# %%
from matplotlib import pyplot as plt
# import numpy as np
import math
# %matplotlib inline

# ax = plt.subplots()
# # ax.errorbar(y,
# #             yerr=dy,
# #             fmt='-o')

# ax.set_xlabel('x-axis')
# ax.set_ylabel('y-axis')
# ax.set_title('Line plot with error bars')

x = [x for x in range(1,11)]
y = [3,9,21,33,50,77,103,130,166,205]
dy = [2,4,2,4,2,4,2,4,2,4]

lnx = [math.log(num) for num in x]
lny = [math.log(num) for num in y]

ax = plt.subplot()
plt.plot(x,y)
ax.set_xticklabels(x)
ax.set_yticklabels(y)
plt.show()

plt.plot(x,lny)
plt.show()
plt.plot(lnx,lny)
plt.show()
# Out:
# <ipython-input-22-6647c42e2eb5>:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x)
# <ipython-input-22-6647c42e2eb5>:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(y)

# %%
from matplotlib import pyplot as plt
import math

x = [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60]
y = [7.071, 5.947, 5.005, 4.219, 3.540, 2.979, 2.505, 2.109, 1.773, 1.489, 1.250, 1.055, 0.884, 0.742, 0.625, 0.527, 0.439, 0.371, 0.313, 0.259, 0.215]
lny = [math.log(num) for num in y]

ax1 = plt.subplots()
plt.plot(x,y)
#plt.set_xticks(x)
plt.show()

plt.plot(x,lny)
plt.show()
